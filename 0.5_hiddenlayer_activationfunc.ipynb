# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# #dummy activation function
# inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]
# ouptut = []

# for i in inputs:
#     if > 0:
#         output.append(i)

# %%
np.random.seed(0)

def create_data(points, classes):
    X = np.zeros((points*classes, 2))
    y = np.zeros(points*classes, dtype = 'uint8')
    for class_number in range(classes):
        ix = range(points*class_number, points*(class_number+1))
        r = np.linspace(0.0, 1, points)
        t = np.linspace(class_number*4, (class_number+1)*4, points)+ np.random.randn(points)*0.2
        X[ix] = np.c_[r*np.sin(t*2.5), r*np.cos(t*2.5)]
        y[ix] = class_number
    return X, y

print("here")
X, y = create_data(200, 3)

plt.scatter(X[:, 0], X[:,1])
plt.show()

plt.scatter(X[:, 0], X[:,1], c=y, cmap = "brg")
plt.show()
# Out:
# here

# %%
class Layer_Dense:
    #initialize the first layer 
    def __init__(self, n_inputs, n_neurons):
        #define weights and biases
        self.weights = 0.10 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
    #forward the output of the previous layer to this layer (iw+b)    
    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases

class Activation_ReLU:
    def forward(self, inputs):
        self.output = np.maximum(0, inputs)
        
layer1 = Layer_Dense(2,5)
activation1 = Activation_ReLU()

layer1.forward(X)

activation1.forward(layer1.output)
activation1.output

# #this layer's input should be the size of the previous layer's output (4, 5 <- output)
# layer2 = Layer_Dense(5,2)
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.        ],
#        [0.00011077, 0.        , 0.00018096, 0.00035328, 0.0006056 ],
#        [0.        , 0.        , 0.00047149, 0.00047814, 0.00088211],
#        ...,
#        [0.06578535, 0.01651732, 0.        , 0.03221576, 0.03759266],
#        [0.04983793, 0.04315299, 0.        , 0.00568306, 0.        ],
#        [0.07122471, 0.00570668, 0.        , 0.04232009, 0.05419437]])
